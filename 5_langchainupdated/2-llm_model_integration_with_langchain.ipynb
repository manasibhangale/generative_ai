# %%
import os
from dotenv import load_dotenv

load_dotenv()

print("Key loaded:", os.getenv("GROQ_API_KEY") is not None)
# Out:
# Key loaded: True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "llama-3.3-70b-versatile",
    model_provider="groq"
)

response = model.invoke("Who is APJ Abdul Kalam?")
print(response.content)
# Out:
# A.P.J. Abdul Kalam, also known as Avul Pakir Jainulabdeen Abdul Kalam, was a renowned Indian scientist, engineer, and statesman who served as the 11th President of India from 2002 to 2007. He is widely regarded as one of the most influential and inspirational figures in Indian history.
#
# Early Life and Education:
# Abdul Kalam was born on October 15, 1931, in Rameswaram, a small town in the state of Tamil Nadu, India. He came from a humble background and was raised in a family of modest means. Despite the financial constraints, Kalam's parents encouraged his curiosity and passion for learning. He completed his schooling in Rameswaram and later moved to Madras (now Chennai) to pursue higher education.
#
# Career:
# Abdul Kalam's career spanned over five decades, during which he made significant contributions to various fields, including:
#
# 1. **Aerospace Engineering**: Kalam joined the Indian Space Research Organisation (ISRO) in 1969 and worked on several projects, including the development of India's first satellite launch vehicle, SLV-III.
# 2. **Defence Research and Development**: In 1980, Kalam joined the Defence Research and Development Organisation (DRDO) and played a crucial role in the development of India's missile program, including the Agni and Prithvi missiles.
# 3. **Presidency**: In 2002, Abdul Kalam was elected as the 11th President of India, becoming the first scientist to hold the office. During his tenure, he focused on promoting education, science, and technology, and worked to strengthen India's relationships with other countries.
#
# Contributions and Achievements:
# Abdul Kalam's contributions to India's scientific and technological advancements are numerous and significant. Some of his notable achievements include:
#
# * **Missile Man of India**: Kalam's work on the development of India's missile program earned him the nickname "Missile Man of India."
# * **India's Nuclear Program**: He played a key role in India's nuclear program, including the development of the Pokhran-II nuclear test in 1998.
# * **Education and Inspiration**: Kalam was a passionate advocate for education and inspired countless young minds through his writings, speeches, and interactions.
#
# Awards and Honors:
# Abdul Kalam received numerous awards and honors for his contributions, including:
#
# * **Bharat Ratna**: India's highest civilian honor, awarded in 1997
# * **Padma Vibhushan**: India's second-highest civilian honor, awarded in 1990
# * **Padma Bhushan**: India's third-highest civilian honor, awarded in 1981
#
# Legacy:
# Abdul Kalam's legacy extends far beyond his scientific and technological contributions. He inspired a generation of Indians to pursue careers in science, technology, engineering, and mathematics (STEM). His emphasis on education, innovation, and entrepreneurship continues to shape India's development trajectory. Kalam's life and work serve as a testament to the power of hard work, determination, and vision.
#
# Abdul Kalam passed away on July 27, 2015, but his legacy continues to inspire and motivate people around the world.

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

response = model.invoke("Who is APJ Abdul Kalam?")
print(response.content)
# Out:
# APJ Abdul Kalam, also known as Avul Pakir Jainulabdeen Abdul Kalam, was a renowned Indian scientist, engineer, and statesman who served as the 11th President of India from 2002 to 2007. He is widely regarded as one of the most influential and inspirational figures in Indian history.
#
# Early Life and Education:
# Abdul Kalam was born on October 15, 1931, in Rameswaram, a small town in the state of Tamil Nadu, India. He came from a humble background and was the youngest of five children. His father, Jainulabdeen, was a boat owner and a devout Muslim, and his mother, Ashiamma, was a homemaker. Kalam's interest in science and mathematics was encouraged by his parents and teachers, and he went on to study physics at the St. Joseph's College in Tiruchirappalli.
#
# Career:
# Abdul Kalam's career spanned over five decades, during which he made significant contributions to India's space and missile programs. He joined the Indian Space Research Organisation (ISRO) in 1969 and worked on several high-profile projects, including the development of the SLV-III rocket, which launched India's first satellite, Rohini, into space in 1980. He also played a crucial role in the development of the Agni and Prithvi missiles, which are still in use by the Indian military today.
#
# In 1992, Kalam became the Scientific Adviser to the Defence Minister, and in 1999, he was appointed as the Principal Scientific Adviser to the Government of India. His work in these roles helped to establish India as a major player in the global space and defence industries.
#
# Presidency:
# In 2002, Abdul Kalam was elected as the 11th President of India, becoming the first scientist to hold the office. During his presidency, he focused on promoting education, science, and technology, and worked to improve India's relationships with other countries. He was known for his simplicity, humility, and accessibility, and was widely respected by Indians and foreigners alike.
#
# Legacy:
# Abdul Kalam's legacy is immense, and he is remembered as a true patriot and a champion of Indian science and technology. He was awarded numerous honors and awards, including the Bharat Ratna, India's highest civilian award, in 1997. He also wrote several books, including his autobiography, "Wings of Fire," which has been translated into many languages.
#
# After his presidency, Kalam continued to work as a scientist and educator, and was a visiting professor at several Indian universities. He passed away on July 27, 2015, while delivering a lecture at the Indian Institute of Management in Shillong, but his legacy lives on, inspiring generations of Indians and people around the world.
#
# Some of his notable achievements and contributions include:
#
# * Development of the SLV-III rocket and the launch of India's first satellite, Rohini
# * Development of the Agni and Prithvi missiles
# * Establishment of India as a major player in the global space and defence industries
# * Promotion of education, science, and technology in India
# * Inspiration to millions of people around the world through his writings and public speaking
#
# Overall, APJ Abdul Kalam was a true icon and a role model for Indians and people around the world, and his legacy will continue to inspire and motivate future generations.
